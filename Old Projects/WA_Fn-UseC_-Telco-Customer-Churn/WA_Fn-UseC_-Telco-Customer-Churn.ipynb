# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")
print("shape : ",data.shape)
# Out:
# shape :  (7043, 21)

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data["TotalCharges"]=pd.to_numeric(data["TotalCharges"],errors="coerce")
data["TotalCharges"].dtypes
# Out:
# dtype('float64')

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
g = sns.PairGrid(data, hue="Churn")
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
sns.countplot(data["gender"])
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(data["SeniorCitizen"])
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='count'>

# %%
sns.countplot(data["Partner"])
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Partner', ylabel='count'>

# %%
sns.countplot(data["Dependents"])
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %%
sns.countplot(data["Churn"])
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %%
sns.kdeplot(data["tenure"][(data["Churn"] == 'Yes') ],color="Red")
sns.kdeplot(data["tenure"][(data["Churn"] == 'No') ],color="Blue")
plt.legend(["Churn","Not Churn"],loc='upper right')
plt.show()

# %%
sns.kdeplot(data["MonthlyCharges"][(data["Churn"] == 'Yes') ],color="Red")
sns.kdeplot(data["MonthlyCharges"][(data["Churn"] == 'No') ],color="Blue")
plt.legend(["Churn","Not Churn"],loc='upper right')
plt.show()

# %%
fig, axes = plt.subplots(nrows = 1,ncols = 2,figsize = (20,6))
ax = sns.boxplot(x="Churn",y="tenure",data=data,ax=axes[0])
ax = sns.boxplot(x="Churn",y="MonthlyCharges",data=data,ax=axes[1])

# %%
sns.distplot(data["tenure"])
plt.show()
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data["MonthlyCharges"])
plt.show()
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data["TotalCharges"])
plt.show()
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data.dropna(inplace=True)
data.drop("customerID",axis=1,inplace=True)

# %%
data['Churn'].replace(to_replace='Yes', value=1, inplace=True)
data['Churn'].replace(to_replace='No',  value=0, inplace=True)

# %%
data.drop(['Partner', 'Dependents', 'tenure','InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaymentMethod','TotalCharges'],axis=1,inplace=True)

# %%
data = pd.get_dummies(data)
data.head()
# Out:
#    SeniorCitizen  MonthlyCharges  Churn  gender_Female  gender_Male  \
# 0              0           29.85      0              1            0
# 1              0           56.95      0              0            1
# 2              0           53.85      1              0            1
# 3              0           42.30      0              0            1
# 4              0           70.70      1              1            0
#
#    PhoneService_No  PhoneService_Yes  MultipleLines_No  \
# 0                1                 0                 0
# 1                0                 1                 1
# 2                0                 1                 1
# 3                1                 0                 0
# 4                0                 1                 1
#
#    MultipleLines_No phone service  MultipleLines_Yes  PaperlessBilling_No  \
# 0                               1                  0                    0
# ...

# %%
data.hist(bins=50, figsize=(25,15))
plt.show()

# %%
plt.figure(figsize=(30,12))
sns.heatmap(data.corr(),vmax=1, vmin=-1, cmap="YlGnBu", annot=True)
plt.show()

# %%
data.columns
# Out:
# Index(['SeniorCitizen', 'MonthlyCharges', 'Churn', 'gender_Female',
#        'gender_Male', 'PhoneService_No', 'PhoneService_Yes',
#        'MultipleLines_No', 'MultipleLines_No phone service',
#        'MultipleLines_Yes', 'PaperlessBilling_No', 'PaperlessBilling_Yes'],
#       dtype='object')

# %%
X=data.drop("Churn",axis=1)
y=data["Churn"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,shuffle=True)
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression(max_iter=1000,solver='liblinear')
LR.fit(X_train,y_train)
y_pred=LR.predict(X_test)
print("The Score of X_train , y_trian",LR.score(X_train,y_train))
print("The Score of X_test , y_test",LR.score(X_test,y_test))
# Out:
# The Score of X_train , y_trian 0.7236895570906136
# The Score of X_test , y_test 0.7180094786729858

# %%
from sklearn.metrics import confusion_matrix ,f1_score ,precision_score ,classification_report
CM=confusion_matrix(y_test,y_pred)
print(CM)
sns.heatmap(CM)
plt.show()
print(classification_report(y_test,y_pred))
# Out:
# [[1491   46]
#  [ 549   24]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.97      0.83      1537
#            1       0.34      0.04      0.07       573
#
#     accuracy                           0.72      2110
#    macro avg       0.54      0.51      0.45      2110
# weighted avg       0.63      0.72      0.63      2110

# %%
from sklearn.svm import SVC
sv=SVC(kernel='sigmoid',max_iter=1000)
sv.fit(X_train,y_train)
y_pred1=sv.predict(X_test)
print("The Score of X_train , y_trian",sv.score(X_train,y_train))
print("The Score of X_test , y_test",sv.score(X_test,y_test))
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# The Score of X_train , y_trian 0.550995530272247
# The Score of X_test , y_test 0.5791469194312796

# %%
CM=confusion_matrix(y_test,y_pred1)
print(CM)
sns.heatmap(CM)
plt.show()
# Out:
# [[968 569]
#  [319 254]]

# %%
from sklearn.ensemble import GradientBoostingClassifier

GBCModel = GradientBoostingClassifier(n_estimators=800,max_depth=7,random_state=33) 
GBCModel.fit(X_train, y_train)
y_pred2=GBCModel.predict(X_test)
#Calculating Details
print('GBCModel Train Score is : ' , GBCModel.score(X_train, y_train))
print('GBCModel Test Score is : ' , GBCModel.score(X_test, y_test))
# Out:
# GBCModel Train Score is :  0.9410808614384396
# GBCModel Test Score is :  0.6744075829383887

# %%
CM=confusion_matrix(y_test,y_pred2)
print(CM)
sns.heatmap(CM)
plt.show()
# Out:
# [[1233  304]
#  [ 383  190]]

# %%
print(classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.80      0.78      1537
#            1       0.38      0.33      0.36       573
#
#     accuracy                           0.67      2110
#    macro avg       0.57      0.57      0.57      2110
# weighted avg       0.66      0.67      0.67      2110

# %%
from sklearn.naive_bayes import GaussianNB
GNB=GaussianNB()
GNB.fit(X_train,y_train)
y_pred4=GNB.predict(X_test)
print("The Score of X_train , y_trian",GNB.score(X_train,y_train))
print("The Score of X_test , y_test",GNB.score(X_test,y_test))

print(classification_report(y_test,y_pred4))
# Out:
# The Score of X_train , y_trian 0.6647704185290533
# The Score of X_test , y_test 0.6630331753554503
#               precision    recall  f1-score   support
#
#            0       0.78      0.75      0.76      1537
#            1       0.39      0.43      0.41       573
#
#     accuracy                           0.66      2110
#    macro avg       0.59      0.59      0.59      2110
# weighted avg       0.67      0.66      0.67      2110

# %%
from sklearn.neighbors import KNeighborsClassifier
KNC=KNeighborsClassifier()
KNC.fit(X_train,y_train)
y_pred3=KNC.predict(X_test)
print("The Score of X_train , y_trian",KNC.score(X_train,y_train))
print("The Score of X_test , y_test",KNC.score(X_test,y_test))
print(classification_report(y_test,y_pred3))
# Out:
# The Score of X_train , y_trian 0.7970337261275904
# The Score of X_test , y_test 0.7061611374407583
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1537
#            1       0.44      0.28      0.34       573
#
#     accuracy                           0.71      2110
#    macro avg       0.60      0.57      0.58      2110
# weighted avg       0.67      0.71      0.68      2110

# %%
CM=confusion_matrix(y_test,y_pred3)
print(CM)
sns.heatmap(CM)
plt.show()
# Out:
# [[1331  206]
#  [ 414  159]]
