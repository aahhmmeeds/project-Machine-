# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
data.shape
# Out:
# (1470, 35)

# %%
data.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
plt.figure(figsize=(30,15))
sns.heatmap(data.corr(),annot =True,linewidth="0.5",fmt=".3f",cmap='viridis')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.distplot(data['Age'],color='g')
plt.show()
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,6))
sns.distplot(data['DailyRate'],color='g')
plt.show()
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,6))
sns.distplot(data['DistanceFromHome'],color='g')
plt.show()
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,6))
sns.distplot(data['MonthlyIncome'],color='g')
plt.show()
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,6))
sns.distplot(data['StandardHours'],color='g')
plt.show()
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(10,6))
sns.distplot(data['YearsAtCompany'],color='g')
plt.show()
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,6))
sns.distplot(data['YearsInCurrentRole'],color='g')
plt.show()
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,6))
sns.distplot(data['YearsWithCurrManager'],color='g')
plt.show()
# Out:
# C:\Users\Nvidia\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data.hist(bins=50, figsize=(25,15))
plt.show()

# %%
data.drop(['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours','EmployeeNumber','Over18','StandardHours','EmployeeCount'], axis="columns", inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %%
#data['Attrition'].unique()

# %%
#data.Attrition.replace({'Yes':1,'No':0},inplace=True)

# %%
#data['BusinessTravel'].unique()

# %%
#data.BusinessTravel.replace({'Travel_Rarely':2,'Travel_Frequently':1,'Non-Travel':0},inplace=True)

# %%
#data['Department'].unique()

# %%
#data.BusinessTravel.replace({'Sales':2,'Research & Development':1,'Human Resources':0},inplace=True)

# %%
data.Attrition.replace({'Yes':1,'No':0},inplace=True)

# %%
X=data.drop(columns=['Attrition'])
y=data['Attrition']

# %%
X=pd.get_dummies(X,drop_first=True)

# %%
X.head(5)
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41       1102                 1          2                        2
# 1   49        279                 8          1                        3
# 2   37       1373                 2          2                        4
# 3   33       1392                 3          4                        4
# 4   27        591                 2          1                        1
#
#    HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  ...  \
# 0          94               3         2                4           5993  ...
# 1          61               2         2                2           5130  ...
# 2          92               2         1                3           2090  ...
# 3          56               3         1                3           2909  ...
# 4          40               3         1                2           3468  ...
#
#    JobRole_Laboratory Technician  JobRole_Manager  \
# ...

# %%
sns.countplot(x = 'Attrition', data = data, hue = 'Attrition', palette = 'dark')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,shuffle=True)

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression(max_iter=1000,solver='liblinear')
LR.fit(X_train,y_train)
y_pred=LR.predict(X_test)
print("The Score of X_train , y_trian",LR.score(X_train,y_train))
print("The Score of X_test , y_test",LR.score(X_test,y_test))
# Out:
# The Score of X_train , y_trian 0.8969873663751214
# The Score of X_test , y_test 0.8662131519274376

# %%
from sklearn.metrics import confusion_matrix ,f1_score ,precision_score ,classification_report
CM=confusion_matrix(y_test,y_pred)
print(CM)
sns.heatmap(CM)
plt.show()
print(classification_report(y_test,y_pred))
# Out:
# [[357  18]
#  [ 41  25]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92       375
#            1       0.58      0.38      0.46        66
#
#     accuracy                           0.87       441
#    macro avg       0.74      0.67      0.69       441
# weighted avg       0.85      0.87      0.85       441

# %%
from sklearn.svm import SVC
sv=SVC(kernel='rbf',max_iter=300)
sv.fit(X_train,y_train)
y_pred1=sv.predict(X_test)
print("The Score of X_train , y_trian",sv.score(X_train,y_train))
print("The Score of X_test , y_test",sv.score(X_test,y_test))
# Out:
# The Score of X_train , y_trian 0.8338192419825073
# The Score of X_test , y_test 0.8503401360544217
# C:\Users\Nvidia\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=300).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'

# %%
CM=confusion_matrix(y_test,y_pred1)
print(CM)
sns.heatmap(CM)
plt.show()
# Out:
# [[375   0]
#  [ 66   0]]

# %%
from sklearn.ensemble import GradientBoostingClassifier

GBCModel = GradientBoostingClassifier(n_estimators=100,max_depth=5,random_state=33) 
GBCModel.fit(X_train, y_train)
y_pred2=GBCModel.predict(X_test)
#Calculating Details
print('GBCModel Train Score is : ' , GBCModel.score(X_train, y_train))
print('GBCModel Test Score is : ' , GBCModel.score(X_test, y_test))
# Out:
# GBCModel Train Score is :  1.0
# GBCModel Test Score is :  0.8639455782312925

# %%
CM=confusion_matrix(y_test,y_pred2)
print(CM)
sns.heatmap(CM)
plt.show()
# Out:
# [[364  11]
#  [ 49  17]]

# %%
print(classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92       375
#            1       0.61      0.26      0.36        66
#
#     accuracy                           0.86       441
#    macro avg       0.74      0.61      0.64       441
# weighted avg       0.84      0.86      0.84       441

# %%
from sklearn.naive_bayes import GaussianNB
GNB=GaussianNB()
GNB.fit(X_train,y_train)
y_pred4=GNB.predict(X_test)
print("The Score of X_train , y_trian",GNB.score(X_train,y_train))
print("The Score of X_test , y_test",GNB.score(X_test,y_test))

print(classification_report(y_test,y_pred4))
# Out:
# The Score of X_train , y_trian 0.793002915451895
# The Score of X_test , y_test 0.7777777777777778
#               precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86       375
#            1       0.37      0.67      0.47        66
#
#     accuracy                           0.78       441
#    macro avg       0.65      0.73      0.67       441
# weighted avg       0.85      0.78      0.80       441

# %%
from sklearn.neighbors import KNeighborsClassifier
KNC=KNeighborsClassifier()
KNC.fit(X_train,y_train)
y_pred3=KNC.predict(X_test)
print("The Score of X_train , y_trian",KNC.score(X_train,y_train))
print("The Score of X_test , y_test",KNC.score(X_test,y_test))
print(classification_report(y_test,y_pred3))
# Out:
# The Score of X_train , y_trian 0.8571428571428571
# The Score of X_test , y_test 0.8344671201814059
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91       375
#            1       0.32      0.09      0.14        66
#
#     accuracy                           0.83       441
#    macro avg       0.59      0.53      0.52       441
# weighted avg       0.78      0.83      0.79       441

# %%
CM=confusion_matrix(y_test,y_pred3)
print(CM)
sns.heatmap(CM)
plt.show()
# Out:
# [[362  13]
#  [ 60   6]]
